# %%
#importing the libraries
import matplotlib.pyplot as plt    
import seaborn as sns

# %%
#import pandas
import pandas as pd
data1 = pd.read_csv('pokedex_(Update.04.20).csv')
data2 = pd.read_csv('pokedex_(Update_05.20).csv')
#merge the datasets
merge_data = pd.merge(data1, data2)
merge_data.head()
# Out:
#    Unnamed: 0  pokedex_number  ... against_fairy  status
# 0           0               1  ...           0.5  Normal
# 1           1               2  ...           0.5  Normal
# 2           2               3  ...           0.5  Normal
# 3           3               3  ...           0.5  Normal
# 4           4               4  ...           0.5  Normal
#
# [5 rows x 54 columns]

# %%
def setplt(x = 15, y = 9):
    f, ax = plt.subplots(figsize=(x, y))
    sns.despine(f, left=True, bottom=True)

# %%
merge_data['type_1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Dark', 'Poison',
#        'Electric', 'Ground', 'Ice', 'Fairy', 'Steel', 'Fighting',
#        'Psychic', 'Rock', 'Ghost', 'Dragon', 'Flying'], dtype=object)

# %%
merge_data['type_2'].unique()
# Out:
# array(['Poison', nan, 'Flying', 'Dragon', 'Normal', 'Psychic', 'Steel',
#        'Ground', 'Fairy', 'Grass', 'Fighting', 'Electric', 'Ice', 'Dark',
#        'Ghost', 'Rock', 'Water', 'Fire', 'Bug'], dtype=object)

# %%
merge_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1026 entries, 0 to 1025
# Data columns (total 54 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1026 non-null   int64
#  1   pokedex_number    1026 non-null   int64
#  2   name              1026 non-null   object
#  3   german_name       936 non-null    object
#  4   japanese_name     936 non-null    object
#  5   generation        1026 non-null   int64
#  6   is_sub_legendary  1026 non-null   int64
#  7   is_legendary      1026 non-null   int64
#  8   is_mythical       1026 non-null   int64
#  9   species           1026 non-null   object
#  10  type_number       1026 non-null   int64
#  11  type_1            1026 non-null   object
#  12  type_2            540 non-null    object
#  13  height_m          1026 non-null   float64
#  14  weight_kg         1025 non-null   float64
#  15  abilities_number  1026 non-null   int64
#  16  ability_1         1023 non-null   object
#  17  ability_2         511 non-null    object
#  18  ability_hidden    808 non-null    object
#  19  total_points      1026 non-null   float64
#  20  hp                1026 non-null   float64
#  21  attack            1026 non-null   float64
#  22  defense           1026 non-null   float64
#  23  sp_attack         1026 non-null   float64
#  24  sp_defense        1026 non-null   float64
#  25  speed             1026 non-null   float64
#  26  catch_rate        922 non-null    float64
#  27  base_friendship   922 non-null    float64
#  28  base_experience   922 non-null    float64
#  29  growth_rate       1025 non-null   object
#  30  egg_type_number   1026 non-null   int64
#  31  egg_type_1        1023 non-null   object
#  32  egg_type_2        281 non-null    object
#  33  percentage_male   790 non-null    float64
#  34  egg_cycles        1025 non-null   float64
#  35  against_normal    1026 non-null   float64
#  36  against_fire      1026 non-null   float64
#  37  against_water     1026 non-null   float64
#  38  against_electric  1026 non-null   float64
#  39  against_grass     1026 non-null   float64
#  40  against_ice       1026 non-null   float64
#  41  against_fight     1026 non-null   float64
#  42  against_poison    1026 non-null   float64
#  43  against_ground    1026 non-null   float64
#  44  against_flying    1026 non-null   float64
#  45  against_psychic   1026 non-null   float64
#  46  against_bug       1026 non-null   float64
#  47  against_rock      1026 non-null   float64
#  48  against_ghost     1026 non-null   float64
#  49  against_dragon    1026 non-null   float64
#  50  against_dark      1026 non-null   float64
#  51  against_steel     1026 non-null   float64
#  52  against_fairy     1026 non-null   float64
#  53  status            1026 non-null   object
# dtypes: float64(32), int64(9), object(13)
# memory usage: 440.9+ KB

# %% [markdown]
# **Q1. What is the Count of Pokemon according to Generation ?**

# %%
sns.set_context('notebook', font_scale=1.4)
sns.factorplot(
    x='generation', 
    data=merge_data, 
    kind='count'
).set_axis_labels('Generation', '# of Pokemon');
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# **Q3. What is the Corelation between the Strengths and Weaknesses of the Pokemon with respect to the type?`**

# %%
ag = merge_data[['against_normal','against_fire','against_water','against_electric','against_grass',
'against_ice','against_fight','against_poison','against_ground','against_flying','against_psychic',
'against_bug','against_rock','against_ghost','against_dragon','against_dark','against_steel','against_fairy']]
# Correlation heat map analysis
plt.subplots(figsize=(25,10))
ax = plt.axes()
ax.set_title("Correlation Heatmap")
corr = ag.corr()
sns.heatmap(corr, annot=True, cmap='magma',
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %% [markdown]
# **Q4. How many Type_1 & Type_2 Pokemons are there?**

# %%
sns.factorplot(
    y='type_1',
    data=merge_data,
    kind='count',
    order=merge_data['type_1'].value_counts().index,
    aspect=1.5,
    size=5,
    color='turquoise'
).set_axis_labels('# of Pokemon', 'Type_1')

sns.factorplot(
    y='type_2',
    data=merge_data,
    kind='count',
    order=merge_data['type_2'].value_counts().index,
    aspect=1.5,
    size=5,
    color='grey'
).set_axis_labels('# of Pokemon', 'Type_2');
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3720: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3720: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
merge_data.describe().round()
# Out:
#        Unnamed: 0  pokedex_number  ...  against_steel  against_fairy
# count      1026.0          1026.0  ...         1026.0         1026.0
# mean        514.0           438.0  ...            1.0            1.0
# std         297.0           259.0  ...            1.0            1.0
# min           0.0             1.0  ...            0.0            0.0
# 25%         258.0           214.0  ...            0.0            1.0
# 50%         514.0           434.0  ...            1.0            1.0
# 75%         771.0           664.0  ...            1.0            1.0
# max        1027.0           890.0  ...            4.0            4.0
#
# [8 rows x 41 columns]

# %%
type1, type2 = merge_data.groupby('type_1'), merge_data.groupby('type_2')
print('Type_1 count: {}'.format(len(type1)))
print('Type_2 count: {}'.format(len(type2)))
# Out:
# Type_1 count: 18
# Type_2 count: 18

# %%
useful_data = merge_data.drop(['Unnamed: 0','german_name','japanese_name','species','height_m','weight_kg',
'abilities_number','ability_1','ability_2','ability_hidden','catch_rate','base_friendship',
'base_experience','egg_type_number','egg_type_1','egg_type_2','percentage_male','egg_cycles'],axis = 1)
useful_data
# Out:
#       pokedex_number                            name  ...  against_fairy     status
# 0                  1                       Bulbasaur  ...            0.5     Normal
# 1                  2                         Ivysaur  ...            0.5     Normal
# 2                  3                        Venusaur  ...            0.5     Normal
# 3                  3                   Mega Venusaur  ...            0.5     Normal
# 4                  4                      Charmander  ...            0.5     Normal
# ...              ...                             ...  ...            ...        ...
# 1021             888     Zacian Hero of Many Battles  ...            1.0  Legendary
# 1022             889        Zamazenta Crowned Shield  ...            1.0  Legendary
# 1023             889  Zamazenta Hero of Many Battles  ...            2.0  Legendary
# 1024             890                       Eternatus  ...            1.0  Legendary
# 1025             890             Eternatus Eternamax  ...            1.0  Legendary
#
# [1026 rows x 36 columns]

# %%
useful_data = useful_data.fillna(0)
useful_data.head(20)
# Out:
#     pokedex_number              name  ...  against_fairy  status
# 0                1         Bulbasaur  ...            0.5  Normal
# 1                2           Ivysaur  ...            0.5  Normal
# 2                3          Venusaur  ...            0.5  Normal
# 3                3     Mega Venusaur  ...            0.5  Normal
# 4                4        Charmander  ...            0.5  Normal
# 5                5        Charmeleon  ...            0.5  Normal
# 6                6         Charizard  ...            0.5  Normal
# 7                6  Mega Charizard X  ...            1.0  Normal
# 8                6  Mega Charizard Y  ...            0.5  Normal
# 9                7          Squirtle  ...            1.0  Normal
# 10               8         Wartortle  ...            1.0  Normal
# 11               9         Blastoise  ...            1.0  Normal
# 12               9    Mega Blastoise  ...            1.0  Normal
# 13              10          Caterpie  ...            1.0  Normal
# 14              11           Metapod  ...            1.0  Normal
# 15              12        Butterfree  ...            1.0  Normal
# 16              13            Weedle  ...            0.5  Normal
# 17              14            Kakuna  ...            0.5  Normal
# 18              15          Beedrill  ...            0.5  Normal
# 19              15     Mega Beedrill  ...            0.5  Normal
#
# [20 rows x 36 columns]

# %%
a = useful_data
final_data = a
final_data
# Out:
#       pokedex_number                            name  ...  against_fairy     status
# 0                  1                       Bulbasaur  ...            0.5     Normal
# 1                  2                         Ivysaur  ...            0.5     Normal
# 2                  3                        Venusaur  ...            0.5     Normal
# 3                  3                   Mega Venusaur  ...            0.5     Normal
# 4                  4                      Charmander  ...            0.5     Normal
# ...              ...                             ...  ...            ...        ...
# 1021             888     Zacian Hero of Many Battles  ...            1.0  Legendary
# 1022             889        Zamazenta Crowned Shield  ...            1.0  Legendary
# 1023             889  Zamazenta Hero of Many Battles  ...            2.0  Legendary
# 1024             890                       Eternatus  ...            1.0  Legendary
# 1025             890             Eternatus Eternamax  ...            1.0  Legendary
#
# [1026 rows x 36 columns]

# %%
pokedex = useful_data[['pokedex_number', 'name', 'type_1', 'type_2', 'generation', 'status']]
statistics = pd.merge(
    useful_data,
    pokedex, on='pokedex_number'
    ).loc[:, ['pokedex_number', 'hp', 'attack', 'defense', 'sp_attack', 'sp_defense', 'speed',
          'total_points']]
pokedex.head()
# Out:
#    pokedex_number           name type_1  type_2  generation  status
# 0               1      Bulbasaur  Grass  Poison           1  Normal
# 1               2        Ivysaur  Grass  Poison           1  Normal
# 2               3       Venusaur  Grass  Poison           1  Normal
# 3               3  Mega Venusaur  Grass  Poison           1  Normal
# 4               4     Charmander   Fire       0           1  Normal

# %% [markdown]
# **What is total count of unique(Primary & Secondary)**
#
# ---

# %%
g = final_data[['type_1','type_2','pokedex_number','name','status']]

# %% [markdown]
# ### **List of Pokemon Who have both primary and secondary characterstics.**

# %%
data0 = g.set_index(["type_1", "type_2"])
data0.head(15)
# Out:
#                pokedex_number              name  status
# type_1 type_2
# Grass  Poison               1         Bulbasaur  Normal
#        Poison               2           Ivysaur  Normal
#        Poison               3          Venusaur  Normal
#        Poison               3     Mega Venusaur  Normal
# Fire   0                    4        Charmander  Normal
#        0                    5        Charmeleon  Normal
#        Flying               6         Charizard  Normal
#        Dragon               6  Mega Charizard X  Normal
#        Flying               6  Mega Charizard Y  Normal
# Water  0                    7          Squirtle  Normal
#        0                    8         Wartortle  Normal
#        0                    9         Blastoise  Normal
#        0                    9    Mega Blastoise  Normal
# Bug    0                   10          Caterpie  Normal
#        0                   11           Metapod  Normal

# %% [markdown]
# **How is Stats of pokemon calculated?**

# %%
statistics.head()
# Out:
#    pokedex_number    hp  attack  ...  sp_defense  speed  total_points
# 0               1  45.0    49.0  ...        65.0   45.0         318.0
# 1               2  60.0    62.0  ...        80.0   60.0         405.0
# 2               3  80.0    82.0  ...       100.0   80.0         525.0
# 3               3  80.0    82.0  ...       100.0   80.0         525.0
# 4               3  80.0   100.0  ...       120.0   80.0         625.0
#
# [5 rows x 8 columns]

# %% [markdown]
# **Top Strongest pokemon**

# %%
pk_lt = final_data[['pokedex_number', 'name', 'type_1', 'type_2', 'generation', 'status','hp', 'attack', 'defense', 'sp_attack', 'sp_defense', 'speed',
          'total_points']]
strongest_p = pk_lt.sort_values('total_points',ascending = False)
st = strongest_p.head(10)
st
# Out:
#       pokedex_number                      name  ...  speed total_points
# 1025             890       Eternatus Eternamax  ...  130.0       1125.0
# 189              150             Mega Mewtwo X  ...  130.0        780.0
# 190              150             Mega Mewtwo Y  ...  140.0        780.0
# 456              384             Mega Rayquaza  ...  115.0        780.0
# 452              382             Primal Kyogre  ...   90.0        770.0
# 454              383            Primal Groudon  ...   90.0        770.0
# 928              800            Ultra Necrozma  ...  129.0        754.0
# 1020             888      Zacian Crowned Sword  ...  148.0        720.0
# 582              493                    Arceus  ...  120.0        720.0
# 1022             889  Zamazenta Crowned Shield  ...  128.0        720.0
#
# [10 rows x 13 columns]

# %%
sns.factorplot(
x='total_points',y = 'name',
data=st,
#col='type_1',
kind='bar',
    size = 6,
    aspect = 3,
    #col_wrap=10
    color='turquoise'
).set_axis_labels('total_points', 'name of Pokemon').set_xticklabels(rotation=90);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3720: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# **Top Weakest pokemon**

# %%
weakest_p = pk_lt.sort_values('total_points',ascending = True)
wt = weakest_p.head(10)
wt
# Out:
#       pokedex_number                  name  ... speed total_points
# 869              746  Wishiwashi Solo Form  ...  40.0        175.0
# 232              191               Sunkern  ...  30.0        180.0
# 952              824               Blipbug  ...  45.0        180.0
# 1001             872                  Snom  ...  20.0        185.0
# 349              298               Azurill  ...  20.0        190.0
# 476              401             Kricketot  ...  25.0        194.0
# 315              265               Wurmple  ...  20.0        195.0
# 13                10              Caterpie  ...  45.0        195.0
# 16                13                Weedle  ...  50.0        195.0
# 330              280                 Ralts  ...  40.0        198.0
#
# [10 rows x 13 columns]

# %%
sns.factorplot(
x='total_points',y = 'name',
data=wt,
#col='type_1',
kind='bar',
    size = 6,
    aspect = 3,
    #col_wrap=10
    color='grey',
    #order=.sort_values('total_points').name
).set_axis_labels('total_points', '# of Pokemon').set_xticklabels(rotation=90);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3720: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
b = useful_data.reset_index().sort_values('total_points', ascending=False).head(3)
b = b.rename(columns = {'total_points':'Strength'}, inplace = False)
b
# Out:
#       index  pokedex_number  ... against_fairy     status
# 1025   1025             890  ...           1.0  Legendary
# 189     189             150  ...           2.0  Legendary
# 190     190             150  ...           1.0  Legendary
#
# [3 rows x 37 columns]

# %% [markdown]
# **Q5. What are the most common combinations of primary and secondary type of pokemon?**

# %%
joined = pd.merge(
pokedex,statistics,
on='pokedex_number'
)
medians = joined.groupby(['type_1', 'type_2']).median().loc[:, 'total_points']
dims = (15, 10) #A4 dimensions
fig, ax = plt.subplots(figsize=dims)
sns.heatmap(
medians.unstack(),
linewidths=10, 
cmap='BrBG'
);

# %% [markdown]
# **Q6. What is the relationship between attack and defense of the Pokemons?**

# %%
jntplt = sns.jointplot(x = 'defense', y = 'attack', data = useful_data, kind = 'reg', height = 10, ratio = 10)

# %% [markdown]
# **Q8. What are the Total points of the pokemon according to their  status ?**

# %%
setplt()
scatplt = sns.scatterplot(x = 'hp', y = 'total_points', hue = 'status', data = useful_data)

# %%
mythical = useful_data[useful_data['is_mythical'] == True]
s_mythical = mythical[['name','is_mythical','total_points','hp','attack','defense','sp_attack','sp_defense','speed']]
s_mythical.head()
# Out:
#                     name  is_mythical  ...  sp_defense  speed
# 191                  Mew            1  ...       100.0  100.0
# 296               Celebi            1  ...       100.0  100.0
# 457              Jirachi            1  ...       100.0  100.0
# 458  Deoxys Normal Forme            1  ...        50.0  150.0
# 459  Deoxys Attack Forme            1  ...        20.0  150.0
#
# [5 rows x 9 columns]

# %%
sub_legendary = useful_data[useful_data['is_sub_legendary'] == True]
s_sub_legendary = sub_legendary[['name','is_sub_legendary','total_points','hp','attack','defense','sp_attack','sp_defense','speed']]
s_sub_legendary.head(5)
# Out:
#          name  is_sub_legendary  total_points  ...  sp_attack  sp_defense  speed
# 182  Articuno                 1         580.0  ...       95.0       125.0   85.0
# 183    Zapdos                 1         580.0  ...      125.0        90.0  100.0
# 184   Moltres                 1         580.0  ...      125.0        85.0   90.0
# 287    Raikou                 1         580.0  ...      115.0       100.0  115.0
# 288     Entei                 1         580.0  ...       90.0        75.0  100.0
#
# [5 rows x 9 columns]

# %%
legendary = useful_data[useful_data['is_legendary'] == True]
legendary.head()
# Out:
#      pokedex_number           name  ...  against_fairy     status
# 188             150         Mewtwo  ...            1.0  Legendary
# 189             150  Mega Mewtwo X  ...            2.0  Legendary
# 190             150  Mega Mewtwo Y  ...            1.0  Legendary
# 294             249          Lugia  ...            1.0  Legendary
# 295             250          Ho-oh  ...            0.5  Legendary
#
# [5 rows x 36 columns]

# %% [markdown]
# **What are the Attack and Defense rate amongst normal and legendary pokemon?**

# %%
print("Attack:")
print("\nLegendary")
print(legendary['attack'].mean())
print("\nNormal")
print(useful_data['attack'].mean())
print("\nDefense:")
print("\nLegendary")
print(legendary['defense' ].mean())
print("\nNormal")
print(useful_data['defense'].mean())
# Out:
# Attack:
#
# Legendary
# 125.74358974358974
#
# Normal
# 80.11988304093568
#
# Defense:
#
# Legendary
# 108.2051282051282
#
# Normal
# 74.50194931773879

# %%
print(len(useful_data))
print(len(useful_data[useful_data["is_legendary"] == True]))
# Out:
# 1026
# 39

# %% [markdown]
# **What is the percentage of legendary pokemon?**

# %%
fig = plt.figure()
explod = (0.1,0)
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
langs = useful_data['is_legendary'].value_counts().index
sizes = useful_data['is_legendary'].value_counts().values
ax.pie(sizes, labels = langs,autopct='%1.2f%%', colors = [ 'yellowgreen','lightskyblue'],explode = explod, shadow = True,startangle = 180)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f19eb3f4bd0>,
#   <matplotlib.patches.Wedge at 0x7f19eb4e8290>],
#  [Text(1.1914538849691594, -0.14296027417397109, '0'),
#   Text(-1.0921660719575366, 0.13104682851883626, '1')],
#  [Text(0.6950147662320096, -0.0833934932681498, '96.20%'),
#   Text(-0.5957269483404745, 0.07148008828300159, '3.80%')])

# %% [markdown]
# **Q10. What is the distribution of Legendary Pokemons corresponding to their Powers?**

# %%
fig, ax = plt.subplots(2,3, figsize = (20,10))
# Plotting 
v_plot = sns.boxenplot(x = 'is_legendary', y = "hp", data = useful_data, palette = "Set2", ax = ax[0][0])
v_plot = sns.boxenplot(x = 'is_legendary', y = "attack", data = useful_data, palette = "Set2", ax = ax[0][1])
v_plot = sns.boxenplot(x = 'is_legendary', y = "defense", data = useful_data, palette = "Set2", ax = ax[0][2])
v_plot = sns.boxenplot(x = 'is_legendary', y = "sp_attack", data = useful_data, palette = "Set2", ax = ax[1][0])
v_plot = sns.boxenplot(x = 'is_legendary', y = "sp_defense", data = useful_data, palette = "Set2", ax = ax[1][1])
v_plot = sns.boxenplot(x = 'is_legendary', y = "speed", data = useful_data, palette = "Set2", ax = ax[1][2])
v_plot = sns.boxenplot(x = 'is_legendary', y = "total_points", data = useful_data, palette = "Set2", ax = ax[1][2])

# %% [markdown]
# **Preparing the Data**

# %%
X = useful_data[['hp','attack','defense','sp_attack','sp_defense','speed','total_points']]
y = useful_data[['is_legendary']]

# %%
A = useful_data[['against_normal','against_fire','against_water','against_electric','against_grass','against_ice','against_fight','against_poison','against_ground','against_flying','against_psychic','against_bug','against_rock','against_ghost','against_dragon','against_dark','against_steel','against_fairy']]
b = useful_data[['is_legendary']]

# %% [markdown]
# We split our data into training and testing sets.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
print(len(y_train))
print(len(y_test))
# Out:
# 820
# 206

# %%
print(len(X_train))
print(len(X_test))
# Out:
# 820
# 206

# %% [markdown]
# **Training the Algorithm**

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 50)
classifier.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=50,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %% [markdown]
# **Making Predictions**

# %%
y_pred = classifier.predict(X_test)

# %% [markdown]
# **Evaluate the Algorithm**
#
# Print Confusion Matrix and Classification Report

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
result = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(result)
# Out:
# Confusion Matrix:
# [[193   1]
#  [  3   9]]

# %%
result1 = classification_report(y_test, y_pred)
print("Classification Report:",)
print (result1)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       194
#            1       0.90      0.75      0.82        12
#
#     accuracy                           0.98       206
#    macro avg       0.94      0.87      0.90       206
# weighted avg       0.98      0.98      0.98       206

# %%
result2 = accuracy_score(y_test,y_pred)
print("Accuracy:",result2)
# Out:
# Accuracy: 0.9805825242718447

# %%
classifier.score(X_test, y_test)
# Out:
# 0.9805825242718447

# %%
from sklearn.model_selection import cross_val_score
classifier = RandomForestClassifier(bootstrap = True, max_depth = 3)
cross_val_score(classifier, X, y, cv = 10)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# array([0.99029126, 0.99029126, 1.        , 0.98058252, 0.99029126,
#        0.95145631, 0.98039216, 0.98039216, 0.99019608, 0.99019608])

# %% [markdown]
# **Splitting The training and testing sets**

# %%
from sklearn.tree import DecisionTreeClassifier

X_train, X_test, y_train, y_test = train_test_split(X.values, y.values) 

dt = DecisionTreeClassifier(max_depth=8)

dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=8, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
dt.score(X_test,y_test)
# Out:
# 0.980544747081712

# %%
from sklearn.tree import DecisionTreeClassifier


from sklearn import tree

# %%
z = ['hp','attack','defense','sp_attack','sp_defense','speed','total_points']

# %% [markdown]
# **Visual representation of Decision Tree**

# %%
setplt()

tree.plot_tree(dt,feature_names = z, filled = True);

# %%
print(tree.export_text(dt))
# Out:
# |--- feature_6 <= 647.00
# |   |--- feature_1 <= 29.50
# |   |   |--- feature_1 <= 28.50
# |   |   |   |--- class: 0
# |   |   |--- feature_1 >  28.50
# |   |   |   |--- feature_5 <= 36.50
# |   |   |   |   |--- class: 0
# |   |   |   |--- feature_5 >  36.50
# |   |   |   |   |--- class: 1
# |   |--- feature_1 >  29.50
# |   |   |--- feature_6 <= 595.00
# |   |   |   |--- feature_5 <= 114.00
# |   |   |   |   |--- class: 0
# |   |   |   |--- feature_5 >  114.00
# |   |   |   |   |--- feature_0 <= 54.50
# |   |   |   |   |   |--- feature_0 <= 44.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_0 >  44.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_0 >  54.50
# |   |   |   |   |   |--- class: 0
# |   |   |--- feature_6 >  595.00
# |   |   |   |--- feature_0 <= 96.00
# |   |   |   |   |--- class: 0
# |   |   |   |--- feature_0 >  96.00
# |   |   |   |   |--- feature_0 <= 98.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_0 >  98.50
# |   |   |   |   |   |--- feature_2 <= 120.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_2 >  120.50
# |   |   |   |   |   |   |--- feature_5 <= 64.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_5 >  64.50
# |   |   |   |   |   |   |   |--- class: 1
# |--- feature_6 >  647.00
# |   |--- feature_0 <= 85.00
# |   |   |--- class: 0
# |   |--- feature_0 >  85.00
# |   |   |--- feature_3 <= 125.00
# |   |   |   |--- feature_3 <= 93.00
# |   |   |   |   |--- class: 1
# |   |   |   |--- feature_3 >  93.00
# |   |   |   |   |--- feature_6 <= 690.00
# |   |   |   |   |   |--- feature_6 <= 675.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_6 >  675.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_6 >  690.00
# |   |   |   |   |   |--- class: 0
# |   |   |--- feature_3 >  125.00
# |   |   |   |--- class: 1
